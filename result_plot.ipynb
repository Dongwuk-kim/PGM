# %%
import json
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
with open('Beta_5_k_5_summary_dic.json') as json_file:
    json_data_1 = json.load(json_file)
with open('Beta_5_k_10_summary_dic.json') as json_file:
    json_data_2 = json.load(json_file)
with open('Beta_5_k_15_summary_dic.json') as json_file:
    json_data_3 = json.load(json_file)
    
with open('Beta_5_k_20_summary_dic.json') as json_file:
    json_data_4 = json.load(json_file)
with open('Beta_5_k_25_summary_dic.json') as json_file:
    json_data_5 = json.load(json_file)

# %%
for key in json_data_1 :
    plt.figure()
    plt.title('{}'.format(key))
    plt.plot(json_data_1[key])

# %%
for key in json_data_3 :
    plt.figure()
    plt.title('{}'.format(key))
    plt.plot(json_data_2[key])

# %%
for key in json_data_3 :
    plt.figure()
    plt.title('{}'.format(key))
    plt.plot(json_data_3[key])

# %%
for key in json_data_4 :
    plt.figure()
    plt.title('{}'.format(key))
    plt.plot(json_data_4[key])

# %%
for key in json_data_5 :
    plt.figure()
    plt.title('{}'.format(key))
    plt.plot(json_data_5[key])
